# %%
import pandas as pd

# %%
#城市与省份对应
data_dict1 = {
	"石家庄":"河北",
	"唐山":"河北",
	"秦皇岛":"河北",
	"邯郸":"河北",
	"邢台":"河北",
	"保定":"河北",
	"张家口":"河北",
	"承德":"河北",
	"沧州":"河北",
	"廊坊":"河北",
	"衡水":"河北",
	"太原":"山西",
	"大同":"山西",
	"阳泉":"山西",
	"长治":"山西",
	"晋城":"山西",
	"朔州":"山西",
	"晋中":"山西",
	"运城":"山西",
	"忻州":"山西",
	"临汾":"山西",
	"吕梁":"山西",
	"呼和浩特":"内蒙古",
	"包头":"内蒙古",
	"乌海":"内蒙古",
	"赤峰":"内蒙古",
	"通辽":"内蒙古",
	"鄂尔多斯":"内蒙古",
	"呼伦贝尔":"内蒙古",
	"巴彦淖尔":"内蒙古",
	"乌兰察布":"内蒙古",
	"兴安盟":"内蒙古",
	"锡林郭勒盟":"内蒙古",
	"阿拉善盟":"内蒙古",
	"沈阳":"辽宁",
	"大连":"辽宁",
	"鞍山":"辽宁",
	"抚顺":"辽宁",
	"本溪":"辽宁",
	"丹东":"辽宁",
	"锦州":"辽宁",
	"营口":"辽宁",
	"阜新":"辽宁",
	"辽阳":"辽宁",
	"盘锦":"辽宁",
	"铁岭":"辽宁",
	"朝阳":"辽宁",
	"葫芦岛":"辽宁",
	"长春":"吉林",
	"吉林市":"吉林",
	"四平":"吉林",
	"辽源":"吉林",
	"通化":"吉林",
	"白山":"吉林",
	"松原":"吉林",
	"白城":"吉林",
	"延边朝鲜族自治州":"吉林",
	"哈尔滨":"黑龙江",
	"齐齐哈尔":"黑龙江",
	"鸡西":"黑龙江",
	"鹤岗":"黑龙江",
	"双鸭山":"黑龙江",
	"大庆":"黑龙江",
	"伊春":"黑龙江",
	"佳木斯":"黑龙江",
	"七台河":"黑龙江",
	"牡丹江":"黑龙江",
	"黑河":"黑龙江",
	"绥化":"黑龙江",
	"大兴安岭地区":"黑龙江",
	"南京":"江苏",
	"无锡":"江苏",
	"徐州":"江苏",
	"常州":"江苏",
	"苏州":"江苏",
	"南通":"江苏",
	"连云港":"江苏",
	"淮安":"江苏",
	"盐城":"江苏",
	"扬州":"江苏",
	"镇江":"江苏",
	"泰州":"江苏",
	"宿迁":"江苏",
	"杭州":"浙江",
	"宁波":"浙江",
	"温州":"浙江",
	"嘉兴":"浙江",
	"湖州":"浙江",
	"绍兴":"浙江",
	"金华":"浙江",
	"衢州":"浙江",
	"舟山":"浙江",
	"台州":"浙江",
	"丽水":"浙江",
	"合肥":"安徽",
	"芜湖":"安徽",
	"蚌埠":"安徽",
	"淮南":"安徽",
	"马鞍山":"安徽",
	"淮北":"安徽",
	"铜陵":"安徽",
	"安庆":"安徽",
	"黄山":"安徽",
	"滁州":"安徽",
	"阜阳":"安徽",
	"宿州":"安徽",
	"六安":"安徽",
	"亳州":"安徽",
	"池州":"安徽",
	"宣城":"安徽",
	"福州":"福建",
	"厦门":"福建",
	"莆田":"福建",
	"三明":"福建",
	"泉州":"福建",
	"漳州":"福建",
	"南平":"福建",
	"龙岩":"福建",
	"宁德":"福建",
	"南昌":"江西",
	"景德镇":"江西",
	"萍乡":"江西",
	"九江":"江西",
	"新余":"江西",
	"鹰潭":"江西",
	"赣州":"江西",
	"吉安":"江西",
	"宜春":"江西",
	"抚州":"江西",
	"上饶":"江西",
	"济南":"山东",
	"青岛":"山东",
	"淄博":"山东",
	"枣庄":"山东",
	"东营":"山东",
	"烟台":"山东",
	"潍坊":"山东",
	"济宁":"山东",
	"泰安":"山东",
	"威海":"山东",
	"日照":"山东",
	"莱芜":"山东",
	"临沂":"山东",
	"德州":"山东",
	"聊城":"山东",
	"滨州":"山东",
	"菏泽":"山东",
	"郑州":"河南",
	"开封":"河南",
	"洛阳":"河南",
	"平顶山":"河南",
	"安阳":"河南",
	"鹤壁":"河南",
	"新乡":"河南",
	"焦作":"河南",
	"濮阳":"河南",
	"许昌":"河南",
	"漯河":"河南",
	"三门峡":"河南",
	"南阳":"河南",
	"商丘":"河南",
	"信阳":"河南",
	"周口":"河南",
	"驻马店":"河南",
	"济源":"河南",
	"武汉":"湖北",
	"黄石":"湖北",
	"十堰":"湖北",
	"宜昌":"湖北",
	"宜城":"湖北",
	"潜江":"湖北",
	"襄阳":"湖北",
	"鄂州":"湖北",
	"荆门":"湖北",
	"孝感":"湖北",
	"荆州":"湖北",
	"黄冈":"湖北",
	"咸宁":"湖北",
	"随州":"湖北",
	"恩施土家族苗族自治州":"湖北",
	"仙桃":"湖北",
	"天门":"湖北",
	"长沙":"湖南",
	"株洲":"湖南",
	"湘潭":"湖南",
	"衡阳":"湖南",
	"邵阳":"湖南",
	"岳阳":"湖南",
	"常德":"湖南",
	"张家界":"湖南",
	"益阳":"湖南",
	"郴州":"湖南",
	"永州":"湖南",
	"怀化":"湖南",
	"娄底":"湖南",
	"湘西土家族苗族自治州":"湖南",
	"广州":"广东",
	"韶关":"广东",
	"深圳":"广东",
	"珠海":"广东",
	"汕头":"广东",
	"佛山":"广东",
	"江门":"广东",
	"湛江":"广东",
	"茂名":"广东",
	"肇庆":"广东",
	"惠州":"广东",
	"梅州":"广东",
	"汕尾":"广东",
	"河源":"广东",
	"阳江":"广东",
	"清远":"广东",
	"东莞":"广东",
	"中山":"广东",
	"潮州":"广东",
	"揭阳":"广东",
	"云浮":"广东",
	"南宁":"广西",
	"柳州":"广西",
	"桂林":"广西",
	"梧州":"广西",
	"北海":"广西",
	"防城港":"广西",
	"钦州":"广西",
	"贵港":"广西",
	"玉林":"广西",
	"百色":"广西",
	"贺州":"广西",
	"河池":"广西",
	"来宾":"广西",
	"崇左":"广西",
	"海口":"海南",
	"三亚":"海南",
	"三沙":"海南",
	"儋州":"海南",
	"澄迈县":"海南",
	"陵水黎族自治县":"海南",
	"白沙黎族自治县":"海南",
	"琼海":"海南",
	"琼中黎族苗族自治县":"海南",
	"万宁":"海南",
	"昌江黎族自治县":"海南",
	"文昌":"海南",
	"屯昌县":"海南",
	"东方":"海南",
	"临高县":"海南",
	"乐东黎族自治县":"海南",
	"五指山":"海南",
	"保亭黎族苗族自治县":"海南",
	"定安县":"海南",
	"成都":"四川",
	"自贡":"四川",
	"攀枝花":"四川",
	"泸州":"四川",
	"德阳":"四川",
	"绵阳":"四川",
	"广元":"四川",
	"遂宁":"四川",
	"内江":"四川",
	"乐山":"四川",
	"南充":"四川",
	"眉山":"四川",
	"宜宾":"四川",
	"广安":"四川",
	"达州":"四川",
	"雅安":"四川",
	"巴中":"四川",
	"资阳":"四川",
	"阿坝藏族羌族自治州":"四川",
	"甘孜藏族自治州":"四川",
	"凉山彝族自治州":"四川",
	"贵阳":"贵州",
	"六盘水":"贵州",
	"遵义":"贵州",
	"安顺":"贵州",
	"毕节":"贵州",
	"铜仁":"贵州",
	"黔西南布依族苗族自治州":"贵州",
	"黔东南苗族侗族自治州":"贵州",
	"黔南布依族苗族自治州":"贵州",
	"昆明":"云南",
	"曲靖":"云南",
	"玉溪":"云南",
	"保山":"云南",
	"昭通":"云南",
	"丽江":"云南",
	"普洱":"云南",
	"临沧":"云南",
	"楚雄彝族自治州":"云南",
	"红河哈尼族彝族自治州":"云南",
	"文山壮族苗族自治州":"云南",
	"西双版纳傣族自治州":"云南",
	"大理白族自治州":"云南",
	"德宏傣族景颇族自治州":"云南",
	"怒江傈僳族自治州":"云南",
	"迪庆藏族自治州":"云南",
	"拉萨":"西藏",
	"日喀则":"西藏",
	"昌都":"西藏",
	"林芝":"西藏",
	"山南":"西藏",
	"那曲":"西藏",
	"阿里":"西藏",
	"西安":"陕西",
	"铜川":"陕西",
	"宝鸡":"陕西",
	"咸阳":"陕西",
	"渭南":"陕西",
	"延安":"陕西",
	"汉中":"陕西",
	"榆林":"陕西",
	"安康":"陕西",
	"商洛":"陕西",
	"兰州":"甘肃",
	"嘉峪关":"甘肃",
	"金昌":"甘肃",
	"白银":"甘肃",
	"天水":"甘肃",
	"武威":"甘肃",
	"张掖":"甘肃",
	"平凉":"甘肃",
	"酒泉":"甘肃",
	"庆阳":"甘肃",
	"定西":"甘肃",
	"陇南":"甘肃",
	"临夏回族自治州":"甘肃",
	"甘南藏族自治州":"甘肃",
	"西宁":"青海",
	"海东":"青海",
	"海北藏族自治州":"青海",
	"黄南藏族自治州":"青海",
	"海南藏族自治州":"青海",
	"果洛":"青海",
	"玉树藏族自治州":"青海",
	"海西蒙古族藏族自治州":"青海",
	"银川":"宁夏",
	"石嘴山":"宁夏",
	"吴忠":"宁夏",
	"固原":"宁夏",
	"中卫":"宁夏",
	"乌鲁木齐":"新疆",
	"石河子":"新疆",
	"克拉玛依":"新疆",
	"吐鲁番":"新疆",
	"阿拉尔":"新疆",
	"哈密":"新疆",
	"昌吉回族自治州":"新疆",
	"博尔塔拉蒙古自治州":"新疆",
	"巴音郭楞蒙古自治州":"新疆",
	"阿克苏地区":"新疆",
	"克孜勒苏柯尔克孜自治州":"新疆",
	"喀什地区":"新疆",
	"和田地区":"新疆",
	"伊犁哈萨克自治州":"新疆",
	"塔城地区":"新疆",
	"阿勒泰地区":"新疆",
	"五家渠":"新疆",
	"北屯":"新疆",
	"图木舒克":"新疆",
	"上海":"上海",
	"重庆":"重庆",
	"北京":"北京",
	"天津":"天津",
	"台北市":"台湾",
	"新北市":"台湾"
}

# %%
df = pd.read_excel('visit_login_user2.xlsx',header=None)

df['province'] = df[4].map(data_dict1)

df['province'] = df['province'].fillna(0)

df.to_excel('new1.xlsx',index=False,encoding='gbk')

# %%
#城市与城市排名对应
data_dict2={
	"北京":"一线",
	"上海":"一线",
	"广州":"一线",
	"深圳":"一线",
	"成都":"一线",
	"杭州":"一线",
	"重庆":"一线",
	"武汉":"一线",
	"西安":"一线",
	"苏州":"一线",
	"天津":"一线",
	"南京":"一线",
	"长沙":"一线",
	"郑州":"一线",
	"东莞":"一线",
	"青岛":"一线",
	"沈阳":"一线",
	"宁波":"一线",
	"昆明":"一线",
	"无锡":"二线",
	"佛山":"二线",
	"合肥":"二线",
	"大连":"二线",
	"福州":"二线",
	"厦门":"二线",
	"哈尔滨":"二线",
	"济南":"二线",
	"温州":"二线",
	"南宁":"二线",
	"长春":"二线",
	"泉州":"二线",
	"石家庄":"二线",
	"贵阳":"二线",
	"南昌":"二线",
	"金华":"二线",
	"常州":"二线",
	"南通":"二线",
	"嘉兴":"二线",
	"太原":"二线",
	"徐州":"二线",
	"惠州":"二线",
	"珠海":"二线",
	"中山":"二线",
	"台州":"二线",
	"烟台":"二线",
	"兰州":"二线",
	"绍兴":"二线",
	"海口":"二线",
	"扬州":"二线",
	"汕头":"三线",
	"湖州":"三线",
	"盐城":"三线",
	"潍坊":"三线",
	"保定":"三线",
	"镇江":"三线",
	"洛阳":"三线",
	"泰州":"三线",
	"乌鲁木齐":"三线",
	"临沂":"三线",
	"唐山":"三线",
	"漳州":"三线",
	"赣州":"三线",
	"廊坊":"三线",
	"呼和浩特":"三线",
	"芜湖":"三线",
	"桂林":"三线",
	"银川":"三线",
	"揭阳":"三线",
	"三亚":"三线",
	"遵义":"三线",
	"江门":"三线",
	"济宁":"三线",
	"莆田":"三线",
	"湛江":"三线",
	"绵阳":"三线",
	"淮安":"三线",
	"连云港":"三线",
	"淄博":"三线",
	"宜昌":"三线",
	"邯郸":"三线",
	"上饶":"三线",
	"柳州":"三线",
	"舟山":"三线",
	"咸阳":"三线",
	"九江":"三线",
	"衡阳":"三线",
	"威海":"三线",
	"宁德":"三线",
	"阜阳":"三线",
	"株洲":"三线",
	"丽水":"三线",
	"南阳":"三线",
	"襄阳":"三线",
	"大庆":"三线",
	"沧州":"三线",
	"信阳":"三线",
	"岳阳":"三线",
	"商丘":"三线",
	"肇庆":"三线",
	"清远":"三线",
	"滁州":"三线",
	"龙岩":"三线",
	"荆州":"三线",
	"蚌埠":"三线",
	"新乡":"三线",
	"鞍山":"三线",
	"湘潭":"三线",
	"马鞍山":"三线",
	"三明":"三线",
	"潮州":"三线",
	"梅州":"三线",
	"秦皇岛":"三线",
	"南平":"三线",
	"吉林":"三线",
	"安庆":"三线",
	"泰安":"三线",
	"宿迁":"三线",
	"包头":"三线",
	"彬州":"三线",
	"韶关":"四线",
	"常德":"四线",
	"六安":"四线",
	"汕尾":"四线",
	"西宁":"四线",
	"茂名":"四线",
	"驻马店":"四线",
	"邢台":"四线",
	"南充":"四线",
	"宜春":"四线",
	"大理":"四线",
	"丽江":"四线",
	"延边":"四线",
	"衢州":"四线",
	"黔东南苗族侗族自治州":"四线",
	"景德镇":"四线",
	"开封":"四线",
	"红河":"四线",
	"北海":"四线",
	"黄冈":"四线",
	"东营":"四线",
	"怀化":"四线",
	"阳江":"四线",
	"菏泽":"四线",
	"黔南布依族苗族自治州":"四线",
	"宿州":"四线",
	"日照":"四线",
	"黄石":"四线",
	"周口":"四线",
	"晋中":"四线",
	"许昌":"四线",
	"拉萨":"四线",
	"锦州":"四线",
	"佳木斯":"四线",
	"淮南":"四线",
	"抚州":"四线",
	"营口":"四线",
	"曲靖":"四线",
	"齐齐哈尔":"四线",
	"牡丹江":"四线",
	"河源":"四线",
	"德阳":"四线",
	"邵阳":"四线",
	"孝感":"四线",
	"焦作":"四线",
	"益阳":"四线",
	"张家口":"四线",
	"运城":"四线",
	"大同":"四线",
	"德州":"四线",
	"玉林":"四线",
	"榆林":"四线",
	"平顶山":"四线",
	"盘锦":"四线",
	"渭南":"四线",
	"安阳":"四线",
	"铜仁":"四线",
	"宣城":"四线",
	"永州":"四线",
	"黄山":"四线",
	"西双版纳":"四线",
	"十堰":"四线",
	"宜宾":"四线",
	"丹东":"四线",
	"乐山":"四线",
	"吉安":"四线",
	"宝鸡":"四线",
	"鄂尔多斯":"四线",
	"铜陵":"四线",
	"娄底":"四线",
	"六盘水":"四线",
	"承德":"四线",
	"保山":"四线",
	"毕节":"四线",
	"泸州":"四线",
	"恩施":"四线",
	"安顺":"四线",
	"枣庄":"四线",
	"聊城":"四线",
	"百色":"四线",
	"临汾":"四线",
	"梧州":"四线",
	"亳州":"四线",
	"德宏":"四线",
	"鹰潭":"四线",
	"滨州":"四线",
	"绥化":"四线",
	"眉山":"四线",
	"赤峰":"四线",
	"咸宁":"四线",
	"防城港":"五线",
	"玉溪":"五线",
	"呼伦贝尔":"五线",
	"普洱":"五线",
	"葫芦岛":"五线",
	"雄楚":"五线",
	"衡水":"五线",
	"抚顺":"五线",
	"钦州":"五线",
	"四平":"五线",
	"汉中":"五线",
	"黔西南布依族苗族自治州":"五线",
	"内江":"五线",
	"湘西":"五线",
	"漯河":"五线",
	"新余":"五线",
	"延安":"五线",
	"长治":"五线",
	"文山":"五线",
	"云浮":"五线",
	"贵港":"五线",
	"昭通":"五线",
	"河池":"五线",
	"达州":"五线",
	"淮北":"五线",
	"濮阳":"五线",
	"通化":"五线",
	"松原":"五线",
	"通辽":"五线",
	"广元":"五线",
	"鄂州":"五线",
	"凉山":"五线",
	"张家界":"五线",
	"荆门":"五线",
	"来宾":"五线",
	"忻州":"五线",
	"克拉玛依":"五线",
	"遂宁":"五线",
	"朝阳":"五线",
	"崇左":"五线",
	"辽阳":"五线",
	"广安":"五线",
	"萍乡":"五线",
	"阜新":"五线",
	"吕梁":"五线",
	"池州":"五线",
	"贺州":"五线",
	"本溪":"五线",
	"铁岭":"五线",
	"自贡":"五线",
	"锡林郭勒盟":"五线",
	"白城":"五线",
	"白山":"五线",
	"雅安":"五线",
	"酒泉":"五线",
	"天水":"五线",
	"晋城":"五线",
	"巴彦淖尔":"五线",
	"随州":"五线",
	"兴安":"五线",
	"临沧":"五线",
	"鸡西":"五线",
	"迪庆":"五线",
	"攀枝花":"五线",
	"鹤壁":"五线",
	"黑河":"五线",
	"双鸭山":"五线",
	"三门峡":"五线",
	"安康":"五线",
	"乌兰察布":"五线",
	"庆阳":"五线",
	"伊犁":"五线",
	"儋州":"五线",
	"哈密":"五线",
	"海西蒙古族藏族自治州":"五线",
	"甘孜藏族自治州":"五线",
	"伊春":"五线",
	"陇南":"五线",
	"乌海":"五线",
	"林芝":"五线",
	"怒江":"五线",
	"朔州":"五线",
	"阳泉":"五线",
	"嘉峪关":"五线",
	"鹤岗":"五线",
	"张掖":"五线",
	"辽源":"五线",
	"吴忠":"五线",
	"昌吉回族自治州":"五线",
	"大兴安岭地区":"五线",
	"巴音郭楞蒙古自治州":"五线",
	"阿坝藏族羌族自治州":"五线",
	"日喀则":"五线",
	"阿拉善盟":"五线",
	"巴中":"五线",
	"平凉":"五线",
	"阿克苏地区":"五线",
	"定西":"五线",
	"商洛":"五线",
	"金昌":"五线",
	"七台河":"五线",
	"石嘴山":"五线",
	"白银":"五线",
	"铜川":"五线",
	"武威":"五线",
	"吐鲁番":"五线",
	"固原":"五线",
	"山南":"五线",
	"临夏回族自治州":"五线",
	"海东":"五线",
	"喀什地区":"五线",
	"甘南藏族自治州":"五线",
	"昌都":"五线",
	"中卫":"五线",
	"资阳":"五线",
	"阿勒泰地区":"五线",
	"塔城地区":"五线",
	"博尔塔拉蒙古自治州":"五线",
	"海南":"五线",
	"克孜勒苏柯尔克孜自治州":"五线",
	"阿里":"五线",
	"和田地区":"五线",
	"玉树藏族自治州":"五线",
	"那曲":"五线",
	"黄南藏族自治州":"五线",
	"海北藏族自治州":"五线",
	"果洛":"五线",
	"三沙":"五线",
}

# %%
df = pd.read_excel('visit_login_user2.xlsx',header=None)

df['cityrank'] = df[4].map(data_dict2)

df['cityrank'] = df['cityrank'].fillna(0)

df.to_excel('new2.xlsx',index=False,encoding='gbk')

# %%
data_dict1 = {
	"石家庄":"河北",
	"唐山":"河北",
	"秦皇岛":"河北",
	"邯郸":"河北",
	"邢台":"河北",
	"保定":"河北",
	"张家口":"河北",
	"承德":"河北",
	"沧州":"河北",
	"廊坊":"河北",
	"衡水":"河北",
	"太原":"山西",
	"大同":"山西",
	"阳泉":"山西",
	"长治":"山西",
	"晋城":"山西",
	"朔州":"山西",
	"晋中":"山西",
	"运城":"山西",
	"忻州":"山西",
	"临汾":"山西",
	"吕梁":"山西",
	"呼和浩特":"内蒙古",
	"包头":"内蒙古",
	"乌海":"内蒙古",
	"赤峰":"内蒙古",
	"通辽":"内蒙古",
	"鄂尔多斯":"内蒙古",
	"呼伦贝尔":"内蒙古",
	"巴彦淖尔":"内蒙古",
	"乌兰察布":"内蒙古",
	"兴安盟":"内蒙古",
	"锡林郭勒盟":"内蒙古",
	"阿拉善盟":"内蒙古",
	"沈阳":"辽宁",
	"大连":"辽宁",
	"鞍山":"辽宁",
	"抚顺":"辽宁",
	"本溪":"辽宁",
	"丹东":"辽宁",
	"锦州":"辽宁",
	"营口":"辽宁",
	"阜新":"辽宁",
	"辽阳":"辽宁",
	"盘锦":"辽宁",
	"铁岭":"辽宁",
	"朝阳":"辽宁",
	"葫芦岛":"辽宁",
	"长春":"吉林",
	"吉林市":"吉林",
	"四平":"吉林",
	"辽源":"吉林",
	"通化":"吉林",
	"白山":"吉林",
	"松原":"吉林",
	"白城":"吉林",
	"延边朝鲜族自治州":"吉林",
	"哈尔滨":"黑龙江",
	"齐齐哈尔":"黑龙江",
	"鸡西":"黑龙江",
	"鹤岗":"黑龙江",
	"双鸭山":"黑龙江",
	"大庆":"黑龙江",
	"伊春":"黑龙江",
	"佳木斯":"黑龙江",
	"七台河":"黑龙江",
	"牡丹江":"黑龙江",
	"黑河":"黑龙江",
	"绥化":"黑龙江",
	"大兴安岭地区":"黑龙江",
	"南京":"江苏",
	"无锡":"江苏",
	"徐州":"江苏",
	"常州":"江苏",
	"苏州":"江苏",
	"南通":"江苏",
	"连云港":"江苏",
	"淮安":"江苏",
	"盐城":"江苏",
	"扬州":"江苏",
	"镇江":"江苏",
	"泰州":"江苏",
	"宿迁":"江苏",
	"杭州":"浙江",
	"宁波":"浙江",
	"温州":"浙江",
	"嘉兴":"浙江",
	"湖州":"浙江",
	"绍兴":"浙江",
	"金华":"浙江",
	"衢州":"浙江",
	"舟山":"浙江",
	"台州":"浙江",
	"丽水":"浙江",
	"合肥":"安徽",
	"芜湖":"安徽",
	"蚌埠":"安徽",
	"淮南":"安徽",
	"马鞍山":"安徽",
	"淮北":"安徽",
	"铜陵":"安徽",
	"安庆":"安徽",
	"黄山":"安徽",
	"滁州":"安徽",
	"阜阳":"安徽",
	"宿州":"安徽",
	"六安":"安徽",
	"亳州":"安徽",
	"池州":"安徽",
	"宣城":"安徽",
	"福州":"福建",
	"厦门":"福建",
	"莆田":"福建",
	"三明":"福建",
	"泉州":"福建",
	"漳州":"福建",
	"南平":"福建",
	"龙岩":"福建",
	"宁德":"福建",
	"南昌":"江西",
	"景德镇":"江西",
	"萍乡":"江西",
	"九江":"江西",
	"新余":"江西",
	"鹰潭":"江西",
	"赣州":"江西",
	"吉安":"江西",
	"宜春":"江西",
	"抚州":"江西",
	"上饶":"江西",
	"济南":"山东",
	"青岛":"山东",
	"淄博":"山东",
	"枣庄":"山东",
	"东营":"山东",
	"烟台":"山东",
	"潍坊":"山东",
	"济宁":"山东",
	"泰安":"山东",
	"威海":"山东",
	"日照":"山东",
	"莱芜":"山东",
	"临沂":"山东",
	"德州":"山东",
	"聊城":"山东",
	"滨州":"山东",
	"菏泽":"山东",
	"郑州":"河南",
	"开封":"河南",
	"洛阳":"河南",
	"平顶山":"河南",
	"安阳":"河南",
	"鹤壁":"河南",
	"新乡":"河南",
	"焦作":"河南",
	"濮阳":"河南",
	"许昌":"河南",
	"漯河":"河南",
	"三门峡":"河南",
	"南阳":"河南",
	"商丘":"河南",
	"信阳":"河南",
	"周口":"河南",
	"驻马店":"河南",
	"济源":"河南",
	"武汉":"湖北",
	"黄石":"湖北",
	"十堰":"湖北",
	"宜昌":"湖北",
	"宜城":"湖北",
	"潜江":"湖北",
	"襄阳":"湖北",
	"鄂州":"湖北",
	"荆门":"湖北",
	"孝感":"湖北",
	"荆州":"湖北",
	"黄冈":"湖北",
	"咸宁":"湖北",
	"随州":"湖北",
	"恩施土家族苗族自治州":"湖北",
	"仙桃":"湖北",
	"天门":"湖北",
	"长沙":"湖南",
	"株洲":"湖南",
	"湘潭":"湖南",
	"衡阳":"湖南",
	"邵阳":"湖南",
	"岳阳":"湖南",
	"常德":"湖南",
	"张家界":"湖南",
	"益阳":"湖南",
	"郴州":"湖南",
	"永州":"湖南",
	"怀化":"湖南",
	"娄底":"湖南",
	"湘西土家族苗族自治州":"湖南",
	"广州":"广东",
	"韶关":"广东",
	"深圳":"广东",
	"珠海":"广东",
	"汕头":"广东",
	"佛山":"广东",
	"江门":"广东",
	"湛江":"广东",
	"茂名":"广东",
	"肇庆":"广东",
	"惠州":"广东",
	"梅州":"广东",
	"汕尾":"广东",
	"河源":"广东",
	"阳江":"广东",
	"清远":"广东",
	"东莞":"广东",
	"中山":"广东",
	"潮州":"广东",
	"揭阳":"广东",
	"云浮":"广东",
	"南宁":"广西",
	"柳州":"广西",
	"桂林":"广西",
	"梧州":"广西",
	"北海":"广西",
	"防城港":"广西",
	"钦州":"广西",
	"贵港":"广西",
	"玉林":"广西",
	"百色":"广西",
	"贺州":"广西",
	"河池":"广西",
	"来宾":"广西",
	"崇左":"广西",
	"海口":"海南",
	"三亚":"海南",
	"三沙":"海南",
	"儋州":"海南",
	"澄迈县":"海南",
	"陵水黎族自治县":"海南",
	"白沙黎族自治县":"海南",
	"琼海":"海南",
	"琼中黎族苗族自治县":"海南",
	"万宁":"海南",
	"昌江黎族自治县":"海南",
	"文昌":"海南",
	"屯昌县":"海南",
	"东方":"海南",
	"临高县":"海南",
	"乐东黎族自治县":"海南",
	"五指山":"海南",
	"保亭黎族苗族自治县":"海南",
	"定安县":"海南",
	"成都":"四川",
	"自贡":"四川",
	"攀枝花":"四川",
	"泸州":"四川",
	"德阳":"四川",
	"绵阳":"四川",
	"广元":"四川",
	"遂宁":"四川",
	"内江":"四川",
	"乐山":"四川",
	"南充":"四川",
	"眉山":"四川",
	"宜宾":"四川",
	"广安":"四川",
	"达州":"四川",
	"雅安":"四川",
	"巴中":"四川",
	"资阳":"四川",
	"阿坝藏族羌族自治州":"四川",
	"甘孜藏族自治州":"四川",
	"凉山彝族自治州":"四川",
	"贵阳":"贵州",
	"六盘水":"贵州",
	"遵义":"贵州",
	"安顺":"贵州",
	"毕节":"贵州",
	"铜仁":"贵州",
	"黔西南布依族苗族自治州":"贵州",
	"黔东南苗族侗族自治州":"贵州",
	"黔南布依族苗族自治州":"贵州",
	"昆明":"云南",
	"曲靖":"云南",
	"玉溪":"云南",
	"保山":"云南",
	"昭通":"云南",
	"丽江":"云南",
	"普洱":"云南",
	"临沧":"云南",
	"楚雄彝族自治州":"云南",
	"红河哈尼族彝族自治州":"云南",
	"文山壮族苗族自治州":"云南",
	"西双版纳傣族自治州":"云南",
	"大理白族自治州":"云南",
	"德宏傣族景颇族自治州":"云南",
	"怒江傈僳族自治州":"云南",
	"迪庆藏族自治州":"云南",
	"拉萨":"西藏",
	"日喀则":"西藏",
	"昌都":"西藏",
	"林芝":"西藏",
	"山南":"西藏",
	"那曲":"西藏",
	"阿里":"西藏",
	"西安":"陕西",
	"铜川":"陕西",
	"宝鸡":"陕西",
	"咸阳":"陕西",
	"渭南":"陕西",
	"延安":"陕西",
	"汉中":"陕西",
	"榆林":"陕西",
	"安康":"陕西",
	"商洛":"陕西",
	"兰州":"甘肃",
	"嘉峪关":"甘肃",
	"金昌":"甘肃",
	"白银":"甘肃",
	"天水":"甘肃",
	"武威":"甘肃",
	"张掖":"甘肃",
	"平凉":"甘肃",
	"酒泉":"甘肃",
	"庆阳":"甘肃",
	"定西":"甘肃",
	"陇南":"甘肃",
	"临夏回族自治州":"甘肃",
	"甘南藏族自治州":"甘肃",
	"西宁":"青海",
	"海东":"青海",
	"海北藏族自治州":"青海",
	"黄南藏族自治州":"青海",
	"海南藏族自治州":"青海",
	"果洛":"青海",
	"玉树藏族自治州":"青海",
	"海西蒙古族藏族自治州":"青海",
	"银川":"宁夏",
	"石嘴山":"宁夏",
	"吴忠":"宁夏",
	"固原":"宁夏",
	"中卫":"宁夏",
	"乌鲁木齐":"新疆",
	"石河子":"新疆",
	"克拉玛依":"新疆",
	"吐鲁番":"新疆",
	"阿拉尔":"新疆",
	"哈密":"新疆",
	"昌吉回族自治州":"新疆",
	"博尔塔拉蒙古自治州":"新疆",
	"巴音郭楞蒙古自治州":"新疆",
	"阿克苏地区":"新疆",
	"克孜勒苏柯尔克孜自治州":"新疆",
	"喀什地区":"新疆",
	"和田地区":"新疆",
	"伊犁哈萨克自治州":"新疆",
	"塔城地区":"新疆",
	"阿勒泰地区":"新疆",
	"五家渠":"新疆",
	"北屯":"新疆",
	"图木舒克":"新疆",
	"上海":"上海",
	"重庆":"重庆",
	"北京":"北京",
	"天津":"天津",
	"台北市":"台湾",
	"新北市":"台湾",
    "$":"0"
}
df = pd.read_excel('user_visit_login_result.xlsx',header=None)
df['province'] = df[4].map(data_dict1)
df['province'] = df['province'].fillna(0)
df.to_excel('new3.xlsx',index=False,encoding='gbk')

# %%
#城市与城市排名对应
data_dict2={
	"北京":"一线",
	"上海":"一线",
	"广州":"一线",
	"深圳":"一线",
	"成都":"一线",
	"杭州":"一线",
	"重庆":"一线",
	"武汉":"一线",
	"西安":"一线",
	"苏州":"一线",
	"天津":"一线",
	"南京":"一线",
	"长沙":"一线",
	"郑州":"一线",
	"东莞":"一线",
	"青岛":"一线",
	"沈阳":"一线",
	"宁波":"一线",
	"昆明":"一线",
	"无锡":"二线",
	"佛山":"二线",
	"合肥":"二线",
	"大连":"二线",
	"福州":"二线",
	"厦门":"二线",
	"哈尔滨":"二线",
	"济南":"二线",
	"温州":"二线",
	"南宁":"二线",
	"长春":"二线",
	"泉州":"二线",
	"石家庄":"二线",
	"贵阳":"二线",
	"南昌":"二线",
	"金华":"二线",
	"常州":"二线",
	"南通":"二线",
	"嘉兴":"二线",
	"太原":"二线",
	"徐州":"二线",
	"惠州":"二线",
	"珠海":"二线",
	"中山":"二线",
	"台州":"二线",
	"烟台":"二线",
	"兰州":"二线",
	"绍兴":"二线",
	"海口":"二线",
	"扬州":"二线",
	"汕头":"三线",
	"湖州":"三线",
	"盐城":"三线",
	"潍坊":"三线",
	"保定":"三线",
	"镇江":"三线",
	"洛阳":"三线",
	"泰州":"三线",
	"乌鲁木齐":"三线",
	"临沂":"三线",
	"唐山":"三线",
	"漳州":"三线",
	"赣州":"三线",
	"廊坊":"三线",
	"呼和浩特":"三线",
	"芜湖":"三线",
	"桂林":"三线",
	"银川":"三线",
	"揭阳":"三线",
	"三亚":"三线",
	"遵义":"三线",
	"江门":"三线",
	"济宁":"三线",
	"莆田":"三线",
	"湛江":"三线",
	"绵阳":"三线",
	"淮安":"三线",
	"连云港":"三线",
	"淄博":"三线",
	"宜昌":"三线",
	"邯郸":"三线",
	"上饶":"三线",
	"柳州":"三线",
	"舟山":"三线",
	"咸阳":"三线",
	"九江":"三线",
	"衡阳":"三线",
	"威海":"三线",
	"宁德":"三线",
	"阜阳":"三线",
	"株洲":"三线",
	"丽水":"三线",
	"南阳":"三线",
	"襄阳":"三线",
	"大庆":"三线",
	"沧州":"三线",
	"信阳":"三线",
	"岳阳":"三线",
	"商丘":"三线",
	"肇庆":"三线",
	"清远":"三线",
	"滁州":"三线",
	"龙岩":"三线",
	"荆州":"三线",
	"蚌埠":"三线",
	"新乡":"三线",
	"鞍山":"三线",
	"湘潭":"三线",
	"马鞍山":"三线",
	"三明":"三线",
	"潮州":"三线",
	"梅州":"三线",
	"秦皇岛":"三线",
	"南平":"三线",
	"吉林":"三线",
	"安庆":"三线",
	"泰安":"三线",
	"宿迁":"三线",
	"包头":"三线",
	"彬州":"三线",
	"韶关":"四线",
	"常德":"四线",
	"六安":"四线",
	"汕尾":"四线",
	"西宁":"四线",
	"茂名":"四线",
	"驻马店":"四线",
	"邢台":"四线",
	"南充":"四线",
	"宜春":"四线",
	"大理":"四线",
	"丽江":"四线",
	"延边":"四线",
	"衢州":"四线",
	"黔东南苗族侗族自治州":"四线",
	"景德镇":"四线",
	"开封":"四线",
	"红河":"四线",
	"北海":"四线",
	"黄冈":"四线",
	"东营":"四线",
	"怀化":"四线",
	"阳江":"四线",
	"菏泽":"四线",
	"黔南布依族苗族自治州":"四线",
	"宿州":"四线",
	"日照":"四线",
	"黄石":"四线",
	"周口":"四线",
	"晋中":"四线",
	"许昌":"四线",
	"拉萨":"四线",
	"锦州":"四线",
	"佳木斯":"四线",
	"淮南":"四线",
	"抚州":"四线",
	"营口":"四线",
	"曲靖":"四线",
	"齐齐哈尔":"四线",
	"牡丹江":"四线",
	"河源":"四线",
	"德阳":"四线",
	"邵阳":"四线",
	"孝感":"四线",
	"焦作":"四线",
	"益阳":"四线",
	"张家口":"四线",
	"运城":"四线",
	"大同":"四线",
	"德州":"四线",
	"玉林":"四线",
	"榆林":"四线",
	"平顶山":"四线",
	"盘锦":"四线",
	"渭南":"四线",
	"安阳":"四线",
	"铜仁":"四线",
	"宣城":"四线",
	"永州":"四线",
	"黄山":"四线",
	"西双版纳":"四线",
	"十堰":"四线",
	"宜宾":"四线",
	"丹东":"四线",
	"乐山":"四线",
	"吉安":"四线",
	"宝鸡":"四线",
	"鄂尔多斯":"四线",
	"铜陵":"四线",
	"娄底":"四线",
	"六盘水":"四线",
	"承德":"四线",
	"保山":"四线",
	"毕节":"四线",
	"泸州":"四线",
	"恩施":"四线",
	"安顺":"四线",
	"枣庄":"四线",
	"聊城":"四线",
	"百色":"四线",
	"临汾":"四线",
	"梧州":"四线",
	"亳州":"四线",
	"德宏":"四线",
	"鹰潭":"四线",
	"滨州":"四线",
	"绥化":"四线",
	"眉山":"四线",
	"赤峰":"四线",
	"咸宁":"四线",
	"防城港":"五线",
	"玉溪":"五线",
	"呼伦贝尔":"五线",
	"普洱":"五线",
	"葫芦岛":"五线",
	"雄楚":"五线",
	"衡水":"五线",
	"抚顺":"五线",
	"钦州":"五线",
	"四平":"五线",
	"汉中":"五线",
	"黔西南布依族苗族自治州":"五线",
	"内江":"五线",
	"湘西":"五线",
	"漯河":"五线",
	"新余":"五线",
	"延安":"五线",
	"长治":"五线",
	"文山":"五线",
	"云浮":"五线",
	"贵港":"五线",
	"昭通":"五线",
	"河池":"五线",
	"达州":"五线",
	"淮北":"五线",
	"濮阳":"五线",
	"通化":"五线",
	"松原":"五线",
	"通辽":"五线",
	"广元":"五线",
	"鄂州":"五线",
	"凉山":"五线",
	"张家界":"五线",
	"荆门":"五线",
	"来宾":"五线",
	"忻州":"五线",
	"克拉玛依":"五线",
	"遂宁":"五线",
	"朝阳":"五线",
	"崇左":"五线",
	"辽阳":"五线",
	"广安":"五线",
	"萍乡":"五线",
	"阜新":"五线",
	"吕梁":"五线",
	"池州":"五线",
	"贺州":"五线",
	"本溪":"五线",
	"铁岭":"五线",
	"自贡":"五线",
	"锡林郭勒盟":"五线",
	"白城":"五线",
	"白山":"五线",
	"雅安":"五线",
	"酒泉":"五线",
	"天水":"五线",
	"晋城":"五线",
	"巴彦淖尔":"五线",
	"随州":"五线",
	"兴安":"五线",
	"临沧":"五线",
	"鸡西":"五线",
	"迪庆":"五线",
	"攀枝花":"五线",
	"鹤壁":"五线",
	"黑河":"五线",
	"双鸭山":"五线",
	"三门峡":"五线",
	"安康":"五线",
	"乌兰察布":"五线",
	"庆阳":"五线",
	"伊犁":"五线",
	"儋州":"五线",
	"哈密":"五线",
	"海西蒙古族藏族自治州":"五线",
	"甘孜藏族自治州":"五线",
	"伊春":"五线",
	"陇南":"五线",
	"乌海":"五线",
	"林芝":"五线",
	"怒江":"五线",
	"朔州":"五线",
	"阳泉":"五线",
	"嘉峪关":"五线",
	"鹤岗":"五线",
	"张掖":"五线",
	"辽源":"五线",
	"吴忠":"五线",
	"昌吉回族自治州":"五线",
	"大兴安岭地区":"五线",
	"巴音郭楞蒙古自治州":"五线",
	"阿坝藏族羌族自治州":"五线",
	"日喀则":"五线",
	"阿拉善盟":"五线",
	"巴中":"五线",
	"平凉":"五线",
	"阿克苏地区":"五线",
	"定西":"五线",
	"商洛":"五线",
	"金昌":"五线",
	"七台河":"五线",
	"石嘴山":"五线",
	"白银":"五线",
	"铜川":"五线",
	"武威":"五线",
	"吐鲁番":"五线",
	"固原":"五线",
	"山南":"五线",
	"临夏回族自治州":"五线",
	"海东":"五线",
	"喀什地区":"五线",
	"甘南藏族自治州":"五线",
	"昌都":"五线",
	"中卫":"五线",
	"资阳":"五线",
	"阿勒泰地区":"五线",
	"塔城地区":"五线",
	"博尔塔拉蒙古自治州":"五线",
	"海南":"五线",
	"克孜勒苏柯尔克孜自治州":"五线",
	"阿里":"五线",
	"和田地区":"五线",
	"玉树藏族自治州":"五线",
	"那曲":"五线",
	"黄南藏族自治州":"五线",
	"海北藏族自治州":"五线",
	"果洛":"五线",
	"三沙":"五线",
    "$":"0"
}
df = pd.read_excel('user_visit_login_result.xlsx',header=None)
df['cityrank'] = df[4].map(data_dict2)
df['cityrank'] = df['cityrank'].fillna(0)
df.to_excel('new4.xlsx',index=False,encoding='gbk')

# %%
b= pd.read_excel('visit_login_user2.xlsx',header=None)
a=b.iloc[:,4]
from collections import Counter

result = Counter(a)
print(result)
# 排序
d = sorted(result.items(), key=lambda x: x[1], reverse=True)
print(d)
# Out:
# Counter({'重庆': 12390, '成都': 3596, '运城': 3538, '广州': 3165, '北京': 2576, '洛阳': 2439, '保定': 2160, '泉州': 1917, '深圳': 1880, '上海': 1650, '郑州': 1639, '西安': 1637, '邯郸': 1604, '东莞': 1484, '衡阳': 1293, '福州': 1282, '贵阳': 1153, '杭州': 1119, '三门峡': 1105, '佛山': 1091, '石家庄': 1007, '天津': 924, '南昌': 885, '临汾': 873, '邢台': 862, '长沙': 852, '苏州': 828, '咸阳': 827, '济南': 793, '济宁': 783, '青岛': 781, '徐州': 732, '合肥': 732, '晋城': 726, '武汉': 721, '唐山': 675, '临沂': 647, '中山': 642, '南京': 637, '德州': 616, '潍坊': 585, '沧州': 572, '惠州': 569, '沈阳': 567, '庆阳': 532, '太原': 519, '厦门': 505, '温州': 460, '烟台': 435, '驻马店': 433, '衡水': 431, '哈尔滨': 416, '菏泽': 413, '乌鲁木齐': 412, '资阳': 410, '廊坊': 399, '长春': 395, '无锡': 392, '长治': 365, '泰安': 359, '濮阳': 355, '大连': 348, '宁波': 343, '南宁': 340, '阜阳': 315, '南阳': 312, '呼和浩特': 307, '开封': 307, '聊城': 304, '银川': 301, '榆林': 300, '金华': 299, '常州': 286, '许昌': 285, '南通': 285, '汕头': 281, '昆明': 281, '达州': 279, '赣州': 278, '南充': 277, '渭南': 272, '张家口': 271, '新乡': 269, '淄博': 266, '湛江': 266, '台州': 259, '吕梁': 258, '
# ...

# %%
#导入相关的第三方模块
import numpy as np
import pandas as pd
import matplotlib as  mpl
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# 用来显示中文标签
mpl.rcParams["font.family"] = "SimHei"
# 用来显示负号
mpl.rcParams["axes.unicode_minus"] = False

# %%
df = pd.read_excel('visit_login_user2 - 副本.xlsx')

# %%
df.head() #显示前五行
# Out:
#             user_id       date      time  first_order_price  age_month  \
# 0  2000001555945280 2018-12-23  11:44:00                0.0         32
# 1  2000001556645220 2019-01-11  09:46:00                0.0        127
# 2  2000001558147370 2019-04-25  22:32:00                0.0         41
# 3  2000001559245920 2019-02-20  12:35:00                0.0         55
# 4  2000001559246030 2019-01-13  08:53:00                0.0         55
#
#   city_num  platform_num  model_num  app_num  main_home  ...  add_friend  \
# 0       广州        9.2969  11.270700        1          0  ...           1
# 1       徐州        9.2969   4.968900        1         17  ...           1
# 2       珠海        9.2969  15.384600        1         41  ...           1
# 3       苏州        9.2969  18.767401        1         34  ...           1
# 4       重庆       13.5570  10.468000        1         31  ...           1
#
#    add_group  camp_num  learn_num  finish_num  study_num  coupon  \
# ...

# %%
df.shape # 数据数量
# Out:
# (106733, 51)

# %%
df.info() # 总体预览
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106733 entries, 0 to 106732
# Data columns (total 51 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   user_id                  106733 non-null  int64
#  1   date                     106733 non-null  datetime64[ns]
#  2   time                     106733 non-null  object
#  3   first_order_price        106733 non-null  float64
#  4   age_month                106733 non-null  int64
#  5   city_num                 106733 non-null  object
#  6   platform_num             106733 non-null  float64
#  7   model_num                106733 non-null  float64
#  8   app_num                  106733 non-null  int64
#  9   main_home                106733 non-null  int64
#  10  main_home2               106733 non-null  int64
#  11  mainpage                 106733 non-null  int64
#  12  schoolreportpage         106733 non-null  int64
# ...

# %%
#日期转出时间格式,按照时间升序排序
df["date"] = pd.to_datetime(df["date"])
df=df.sort_values(by="date",ascending=True)
df.head()
# Out:
#                user_id       date      time  first_order_price  age_month  \
# 6573  2000002355806650 2018-11-16  19:09:00                0.0         43
# 5815  2000002343820510 2018-11-16  16:52:00                0.0         48
# 5816  2000002343821020 2018-11-16  22:11:00                0.0        103
# 5818  2000002343821200 2018-11-16  22:42:00                0.0         42
# 5819  2000002343821330 2018-11-16  11:48:00                0.0         70
#
#      city_num  platform_num  model_num  app_num  main_home  ...  add_friend  \
# 6573       淄博       13.5570    10.9934        1          5  ...           1
# 5815       济宁        9.2969    10.7143        1         61  ...           1
# 5816       南宁       13.5570    13.5328        1        241  ...           1
# 5818       重庆        9.2969    13.3198        1         11  ...           1
# 5819       茂名        9.2969     4.3656        1          3  ...           1
#
# ...

# %%
#体验课每日用户下单数量
df_number=df.groupby("date")["user_id"].count()
print(df_number)
# Out:
# date
# 2018-11-16    1034
# 2018-11-17    1051
# 2018-11-18     808
# 2018-11-19    1184
# 2018-11-20     971
#               ...
# 2019-05-09     207
# 2019-05-10     306
# 2019-05-11     405
# 2019-05-12     482
# 2019-05-13     284
# Name: user_id, Length: 179, dtype: int64

# %%
plt.figure(figsize=(16,10),facecolor='white',edgecolor='white') #设置画布颜色、画布边线颜色
plt.subplot(2,1,1)
plt.plot(df_number,c="r")
plt.title("体验课每日用户下单量")
plt.grid(color='y', linestyle='--', linewidth=0.5)
plt.show()
